# %% [markdown]
#                                                     Matplotlib
#                                                 syed Qasim RAza Fatimi

# %%
import matplotlib

# %%
print(matplotlib.__version__)
# Out:
# 3.5.2

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # pyplots

# %%
x=np.array([2,6])
y=np.array([0,40])
plt.plot(x,y)
plt.show()

# %%
# Plotting Without Line
x=np.array([2,6,8])
y=np.array([0,40,52])
plt.plot(x,y,'o')
plt.show()

# %%
x=np.array([2,6,8])
y=np.array([0,40,52])
plt.plot(x,y)
plt.show()

# %%
# Multiple Points
x = np.array([1, 2, 6, 8])
y = np.array([3, 8, 1, 10])
plt.plot(x,y)
plt.show()

# %%
# Multiple Points/
y = np.array([3, 8, 1, 10])
plt.plot(y)
plt.show()

# %% [markdown]
# # Marker

# %%
# Marker	Description
# 'o'	Circle
# '*'	Star
# '.'	Point
# ','	Pixel
# 'x'	X
# 'X'	X (filled)
# '+'	Plus
# 'P'	Plus (filled)
# 's'	Square
# 'D'	Diamond
# 'd'	Diamond (thin)
# 'p'	Pentagon
# 'H'	Hexagon
# 'h'	Hexagon
# 'v'	Triangle Down
# '^'	Triangle Up
# '<'	Triangle Left
# '>'	Triangle Right
# '1'	Tri Down
# '2'	Tri Up
# '3'	Tri Left
# '4'	Tri Right
# '|'	Vline
# '_'	Hline
y = np.array([3, 8, 1, 10])
plt.plot(y,marker='o')
plt.show()

# %%
y = np.array([3, 8, 1, 10])
plt.plot(y,marker='>')
plt.show()

# %%
#formate string (fmt)

# %%
# Line Reference
# Line Syntax	Description
# '-'	Solid line	
# ':'	Dotted line	
# '--'	Dashed line	
# '-.'	Dashed/dotted line


# Color Reference
# Color Syntax	Description
# 'r'	Red	
# 'g'	Green	
# 'b'	Blue	
# 'c'	Cyan	
# 'm'	Magenta	
# 'y'	Yellow	
# 'k'	Black	
# 'w'	White

# %%
y = np.array([3, 8, 1, 10])
plt.plot(y,'o:r')
plt.show()

# %%
y = np.array([3, 8, 1, 10])
plt.plot(y,'o-.g')
plt.show()

# %%
# Marker Size
y = np.array([3, 11, 5, 10])
plt.plot(y,'o--g',ms=15)
plt.show()

# %%
# Marker Color
# mec:marker edge colour
y = np.array([4, 6, 2, 11])
plt.plot(y,'o:g',ms=15,mec='r')
plt.show()

# %%
# mfc:marker face colour
y = np.array([4, 6, 2, 11])
plt.plot(y,'o-g',ms=15,mec='r',mfc='w')
plt.show()

# %%
# Hexadecimal color values:
y = np.array([4, 6, 2, 11])
plt.plot(y,'o-.g',ms=15,mec='#4CAF50',mfc='#4CAF50')
plt.show()

# %%
#  supported color names.
y = np.array([4, 6, 2, 11])
plt.plot(y,'o-.b',ms=15,mec='red',mfc='Aqua')
plt.show()

# %% [markdown]
# # Matplotlib Line

# %%
# linestyle
y = np.array([4, 6, 2, 11])
plt.plot(y,linestyle=':')
plt.show()

# %%
y = np.array([4, 2, 2,9])
plt.plot(y,ls='dashed')
plt.show()

# %%
# Line Color

# %%
y = np.array([1,4,1,6,1])
plt.plot(y,color='g')
plt.show()

# %%
# Line Width
y = np.array([5,6,8,9])
plt.plot(y,color='g',linewidth='10.5')
plt.show()

# %%
x = np.array([3, 8, 1, 10])
y = np.array([6, 5, 4, 11])
plt.plot(x)
plt.plot(y)
plt.show()

# %%
x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])

plt.plot(x1, y1, x2, y2)
plt.xlabel('time')
plt.ylabel('accleration')
plt.title('Acceralation vs time')
plt.show()

# %%
x=[1,2,3,4,5]
y=[4,5,6,4,6]
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("Sports Watch Data", fontdict = font1)
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)
plt.grid()

plt.plot(x, y,'o-.',mec='w',mfc='g')
plt.show()

# %%
# title on left
x=[1,2,3,4,5]
y=[4,5,6,4,6]
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("Sports Watch Data", fontdict = font1,loc='left')
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)
plt.grid()

plt.plot(x, y,'o-.',mec='w',mfc='g')
plt.show()

# %%
# x_axis
x=[2,3,3.5,5,2]
y=[4,5.3,6,4,4]
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("Sports Watch Data", fontdict = font1,loc='right')
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)
plt.grid(axis='x')

plt.plot(x, y,'o-.',mec='w',mfc='g')
plt.show()

# %% [markdown]
# ## Subplot

# %%
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}
plt.title("Sports Watch Data", fontdict = font1,loc='right')
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)
plt.grid(axis='x')

plt.subplot(1, 2, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.grid(axis='y')

plt.subplot(1, 2, 2)
plt.plot(x,y)

plt.show()

# %%
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")
plt.xlabel('time')
plt.ylabel('money')

plt.suptitle("MY SHOP")
plt.show()

# %%
x=np.array([1,2,4,5,6])
y=np.array([2,4,6,8,10])
plt.subplot(1,2,1)
plt.plot(x,y)
plt.title("my subplot1")

x=np.array([3,6,7,8,6])
y=np.array([3,4,5,6,7])
plt.subplot(1,2,2)
plt.plot(x,y)
plt.title("my subplot2")

plt.suptitle("my Subplot")
plt.show()

# %%
# to change column and row of plot(2rows 2 columns)
x=np.array([1,2,4,5,6])
y=np.array([2,4,6,8,10])
plt.subplot(2,2,1)
plt.plot(x,y)
plt.title("my subplot1")

x=np.array([3,6,7,8,6])
y=np.array([3,4,5,6,7])
plt.subplot(2,2,2)
plt.plot(x,y)
plt.title("my subplot2")

plt.suptitle("my Subplot")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)

plt.show()

# %% [markdown]
# # sacatter

# %%
x=np.array([1,2,4,5,6,3,4])
y=np.array([2,4,6,8,10,34,53])
plt.scatter(x,y)
plt.show()

# %%
x=np.array([1,2,4,5,6,3,4,3,2,6,7,4,1])
y=np.array([2,4,6,8,10,34,53,4,6,10,23,11,24])
plt.scatter(x,y,color="green")

x=np.array([2,3,4,5,1,5,5])
y=np.array([3,6,7,9,4,49,2])
plt.scatter(x,y,color='hotpink')

plt.show()

# %%
x=np.array([1,2,4,5,6,3,4,3,2,6,7,4,1])
y=np.array([2,4,6,8,10,34,53,4,6,10,23,11,24])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])
plt.scatter(x,y,color=colors)

# %%
# colour map
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis',s=102)
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])
plt.scatter(x, y, c=colors, cmap='viridis',s=sizes)
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])
plt.scatter(x, y, c=colors, cmap='viridis',s=sizes,alpha=0.5)
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])
plt.scatter(x, y, c=colors, cmap='nipy_spectral',s=sizes,alpha=0.5)
plt.legend(['qasim'])
plt.show()

# %% [markdown]
# # Bar

# %%
x=np.array([1,2,3,4,5])
y=np.array([2,4,6,8,10])
plt.bar(x,y)
plt.show()

# %%
x=np.array([1,2,3,4,5])
y=np.array([2,4,6,8,10])
plt.barh(x,y)
plt.show()

# %%
x=np.array([1,2,3,4,5])
y=np.array([2,4,6,8,10])
plt.bar(x,y,color='hotpink')
plt.show()

# %%
x=np.array([3,6,9,2,4])
y=np.array([2,4,6,8,10])
plt.bar(x,y,color="#4CAF50",width=0.5)
plt.legend(['qasim'])
plt.show()

# %%
x=np.array([3,6,9,2,4])
y=np.array([2,4,6,8,10])
plt.barh(x,y,color="#4CAF50",height=0.5)
plt.show()

# %% [markdown]
# # Histogram

# %%
x=np.random.normal(100,5,150)
plt.hist(x)
plt.show()

# %%
x=np.array([3,6,9,12])
label=['Qasim','Haider','Wasi','Iqrar']
plt.pie(x,labels=label)
plt.show()

# %%
x=np.array([3,6,9,12])
label=['Qasim','Haider','Wasi','Iqrar']
plt.pie(x,labels=label,startangle=180)
plt.show()

# %%
x=np.array([3,6,9,12])
label=['Qasim','Haider','Wasi','Iqrar']
plt.pie(x,labels=label,startangle=90,explode=[0.09,0.01,0.01,0.01])
plt.show()

# %%
x=np.array([3,6,9,12])
label=['Qasim','Haider','Wasi','Iqrar']
plt.pie(x,labels=label,startangle=270,explode=[0.07,0.01,0.01,0.01],shadow=True)
plt.show()

# %%
x=np.array([3,6,9,12])
label=['Qasim','Haider','Wasi','Iqrar']
colors = ["black", "hotpink", "b", "#4CAF50"]
plt.pie(x,labels=label,startangle=360,explode=[0.07,0.01,0.01,0.01],shadow=True,colors=colors)
plt.show()

# %%
x=np.array([3,6,9,12])
label=['Qasim','Haider','Wasi','Iqrar']
colors = ["black", "hotpink", "b", "#4CAF50"]
plt.pie(x,labels=label,startangle=360,explode=[0.07,0.01,0.01,0.01],shadow=True,colors=colors, autopct='%1.1f%%')
plt.legend(title='Four Friend',loc="lower left")
plt.show()

# %%
# make data
x=np.array([1,2,3,3,4])
y=np.array([1,2,3,4,5])
# plot
fig, ax = plt.subplots()

ax.hexbin(x, y, gridsize=20)

plt.show()
